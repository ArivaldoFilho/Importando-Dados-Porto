# %%
import pandas as pd

# %%
relatorio = pd.read_html(r'https://www.gov.br/infraestrutura/pt-br/assuntos/transporte_aquaviario/sistema-portuario', header=1) [1]
display(relatorio)
# Out:
#                       Porto Estado  Autoridade Portuária      Tipo
# 0            Porto de SUAPE     PE                 SUAPE  Marítimo
# 1         Porto de IMBITUBA     SC                 SCPAR  Marítimo
# 2           Porto de LAGUNA     SC                 SCPAR  Marítimo
# 3   Porto de SÃO FRANC. SUL     SC                 SCPAR  Marítimo
# 4           Porto de ITAQUI     MA                  EMAP  Marítimo
# 5         Porto de CABEDELO     PB              DOCAS-PB  Marítimo
# 6           Porto do RECIFE     PE  PORTO DO RECIFE S.A.  Marítimo
# 7    Porto de SÃO SEBASTIÃO     SP                  CDSS  Marítimo
# 8         Porto de ANTONINA     PR                  APPA  Marítimo
# 9        Porto de PARANAGUÁ     PR                  APPA  Marítimo
# 10         Porto de PELOTAS     RS              PORTO RS  Marítimo
# 11    Porto de PORTO ALEGRE     RS              PORTO RS  Marítimo
# 12      Porto de RIO GRANDE     RS              PORTO RS  Marítimo
# ...
